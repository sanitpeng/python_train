# %% [markdown]
# ### 3S Quant System Demo：
#
# ![](../img/3S_logo.png)

# %%
# %matplotlib inline
import widget_loop_back
widget_loop_back.show_ui()
# Out:
# VkJveChjaGlsZHJlbj0oVGFiKGNoaWxkcmVuPShWQm94KGNoaWxkcmVuPShCb3VuZGVkSW50VGV4dCh2YWx1ZT0xMDAwMDAsIGRlc2NyaXB0aW9uPXUnXHU1MjFkXHU1OWNiXHU4ZDQ0XHU5MWTigKY=
# 提示
# 曲线投影mfi:80 j:100卖出策略已添加成功！
# 牛熊线数据:
# 开始日期   结束日期     开始价格   结束价格    角 度     步长    斜率验证
# 2016-12-12 2017-03-14   21.649      20.076       0.000     59
# 2017-03-14 2017-05-25   20.076      19.080       0.000     49
# 2017-05-25 2018-04-04   19.080      31.900       0.000     207
# 2018-04-04 2018-09-18   31.900      23.000       0.000     114
# 2018-09-18 2018-12-10   23.000      25.000       0.000     53
# symbol 's ma(10) is sliced in 21 slices
# 均线切片数据:
# 开始日期   结束日期     开始价格   结束价格    角 度     步长    斜率验证
# 2016-12-12 2016-12-22   21.649      19.183       0.000     009      0.000
# 2016-12-23 2016-12-30   18.894      19.127      -8.752     006      19.201
# 2017-01-03 2017-03-09   19.294      19.089      -0.325     042      19.039
# 2017-03-10 2017-03-24   19.173      20.002       4.681     011      19.925
# ...

# %% [markdown]
# 3S 量化系统 demo
